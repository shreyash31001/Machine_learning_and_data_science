# %%
import warnings 
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt 
# %matplotlib inline

# %% [markdown]
# # problem statement: predict the quality of wine and also find out features that will influence the wine quality

# %%
data = pd.read_csv('winequal.csv')
data['quality'] = data['quality']  - 3
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        2
# 1      9.8        2
# 2      9.8        2
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
data.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        2
# 1      9.8        2
# 2      9.8        2
# ...

# %% [markdown]
# # Data visualization

# %% [raw]
# # For feature understanding (since it is a numerical data) we use
# # Scatter plot
# # histogram (distplot)
# # Box plot
# # It will help us understand the data

# %%
#Scatter plot to check for correlation 
plt.scatter(x="pH", y = "quality", data = data, marker = 'o', c = 'r')
plt.xlabel('pH', fontsize = 15)
plt.ylabel('quality', fontsize=15)
plt.show()

# %%
sns.lmplot(x="pH", y="quality",data= data )
plt.show()

# %%
#Scatter plot fixed acidity	volatile acidity
plt.scatter(x = "alcohol", y = "fixed acidity", data = data)
plt.xlabel("alcohol", fontsize = 15)
plt.ylabel("fixed acidity", fontsize =  15)
plt.show()

# %%
sns.lmplot(x="alcohol", y="fixed acidity",data= data )
plt.show()

# %%
sns.countplot(x="quality", data = data)
# Out:
# <Axes: xlabel='quality', ylabel='count'>

# %% [markdown]
# # To check for outliers in data

# %%
sns.distplot(data['quality'], bins = 6)
plt.show()
# Out:
# C:\Users\shrey\AppData\Local\Temp\ipykernel_23076\2999117897.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['quality'], bins = 6)

# %%
sns.boxplot(data['quality'])
# Out:
# <Axes: >

# %%
#distplot and boxplot
# for column in data.columns[1:]:
#     sns.boxplot(data[column])
#     sns.distplot(data[column])

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
sns.boxplot(data['volatile acidity'])
plt.subplot(1,2,2)
sns.distplot(data['volatile acidity'])
# Out:
# C:\Users\shrey\AppData\Local\Temp\ipykernel_23076\1078371160.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['volatile acidity'])
# <Axes: xlabel='volatile acidity', ylabel='Density'>

# %%
warnings.filterwarnings("ignore")
fig,ax = plt.subplots(12,2, figsize=(5,80))
for index, i in enumerate(data.columns):
    sns.distplot(data[i], ax = ax[index, 0])
    sns.boxplot(data[i], ax=ax[index,1])
    
fig.tight_layout()
fig.subplots_adjust(top = 0.95)
plt.suptitle('Visualizing columns')
# Out:
# Text(0.5, 0.98, 'Visualizing columns')

# %% [raw]
# # We can observe there are outliers in the data

# %% [markdown]
# # Feature relationships
#
# To find the relationships between features
#
# Heatmap,
# Scatter plot,
# Bar plot,

# %%
plt.figure(figsize = (12,10))
new_data = data.corr()
sns.heatmap(new_data, annot = True)
plt.show()

# %%
plt.figure(figsize=(10,6))  #for setting the plot size
plt.title('Quality vs pH')  #add title
sns.barplot(x='quality',y='pH',data=data)
# Out:
# <Axes: title={'center': 'Quality vs pH'}, xlabel='quality', ylabel='pH'>

# %%
plt.figure(figsize=(10,6))  #for setting the plot size
plt.title('Quality vs alcohol')  #add title
sns.barplot(x='quality',y='alcohol',data=data)
# Out:
# <Axes: title={'center': 'Quality vs alcohol'}, xlabel='quality', ylabel='alcohol'>

# %%
data_1 = data 
data_1.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        2
# 1      9.8        2
# 2      9.8        2
# ...

# %%
x = data_1.drop("quality", axis=True)
y = data_1["quality"]

# %%
from sklearn.ensemble import ExtraTreesClassifier
model = ExtraTreesClassifier()
model.fit(x,y)
# Out:
# ExtraTreesClassifier()

# %%
print(model.feature_importances_)
# Out:
# [0.07518436 0.098279   0.08037128 0.07858397 0.07763017 0.07425956
#  0.10243529 0.08487668 0.0771028  0.10242689 0.14885001]

# %%
feat_importances = pd.Series(model.feature_importances_,index = x.columns)
feat_importances.plot(kind="barh")
plt.show()

# %%
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
X_train, X_test, y_train, y_test = train_test_split(
    x, y, test_size = 0.2, random_state = 42)

# %%
xgb_cl = xgb.XGBClassifier()

# %%
xgb_cl.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               objective='multi:softprob', predictor=None, ...)

# %%
preds = xgb_cl.predict(X_test)

# %%
preds
# Out:
# array([2, 2, 2, 2, 3, 2, 2, 2, 3, 3, 4, 2, 3, 2, 3, 4, 3, 3, 4, 2, 2, 3,
#        2, 3, 3, 3, 3, 2, 3, 3, 2, 3, 3, 3, 3, 2, 3, 3, 2, 3, 2, 2, 3, 2,
#        2, 3, 3, 3, 2, 3, 2, 2, 3, 4, 2, 3, 3, 3, 3, 2, 3, 3, 2, 2, 3, 3,
#        4, 2, 4, 3, 3, 2, 3, 3, 3, 2, 3, 2, 3, 3, 2, 4, 2, 3, 3, 3, 2, 3,
#        4, 3, 3, 2, 2, 2, 2, 2, 2, 4, 2, 3, 2, 2, 3, 4, 3, 4, 3, 2, 1, 2,
#        3, 2, 4, 2, 2, 3, 3, 2, 2, 3, 3, 3, 3, 2, 3, 2, 3, 3, 2, 3, 3, 2,
#        2, 3, 3, 2, 2, 2, 2, 3, 4, 3, 4, 2, 2, 2, 3, 3, 3, 2, 3, 3, 3, 2,
#        3, 2, 2, 4, 2, 3, 2, 3, 3, 2, 2, 3, 3, 2, 2, 2, 2, 2, 4, 2, 4, 3,
#        3, 2, 2, 2, 2, 3, 3, 3, 2, 3, 3, 3, 4, 2, 2, 2, 2, 3, 3, 2, 1, 3,
#        3, 4, 2, 2, 2, 2, 4, 2, 2, 3, 3, 4, 5, 2, 2, 3, 3, 4, 3, 2, 3, 3,
#        3, 3, 3, 4, 3, 2, 2, 4, 2, 2, 2, 2, 4, 3, 2, 4, 2, 3, 3, 2, 2, 2,
#        3, 4, 2, 4, 3, 3, 3, 2, 3, 3, 2, 3, 3, 2, 2, 2, 3, 3, 3, 2, 2, 4,
#        3, 4, 3, 2, 3, 3, 2, 3, 2, 3, 3, 2, 3, 5, 3, 3, 4, 2, 2, 2, 2, 4,
# ...

# %%
accuracy_score(y_test, preds)
# Out:
# 0.675

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()

# %%
classifier
# Out:
# LogisticRegression()

# %%
classifier.fit(X_train, y_train)
# Out:
# C:\Users\shrey\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred = classifier.predict(X_test)

# %%
y_pred
# Out:
# array([2, 2, 2, 2, 3, 2, 2, 2, 3, 3, 3, 2, 2, 2, 2, 3, 2, 2, 3, 2, 3, 2,
#        3, 3, 2, 2, 3, 2, 2, 3, 2, 2, 3, 2, 2, 2, 3, 3, 3, 3, 2, 2, 3, 2,
#        3, 3, 3, 2, 2, 3, 2, 2, 3, 3, 2, 2, 3, 2, 3, 2, 2, 3, 2, 2, 3, 2,
#        3, 2, 3, 2, 3, 2, 3, 3, 3, 2, 3, 3, 3, 3, 2, 3, 2, 3, 3, 3, 2, 3,
#        3, 2, 3, 2, 3, 3, 2, 3, 2, 3, 2, 2, 2, 2, 3, 3, 3, 3, 3, 2, 3, 2,
#        3, 2, 3, 2, 3, 3, 3, 2, 2, 3, 3, 2, 2, 2, 2, 2, 3, 3, 2, 3, 3, 2,
#        2, 3, 3, 2, 2, 2, 2, 3, 2, 3, 3, 3, 3, 2, 3, 3, 3, 2, 3, 3, 2, 3,
#        3, 3, 2, 3, 2, 3, 3, 3, 3, 2, 2, 3, 2, 2, 2, 2, 2, 2, 3, 2, 2, 3,
#        3, 2, 2, 2, 2, 3, 2, 4, 2, 3, 2, 3, 3, 2, 3, 3, 3, 3, 3, 2, 2, 2,
#        2, 3, 2, 2, 2, 2, 3, 3, 2, 2, 2, 3, 3, 2, 3, 3, 3, 3, 2, 2, 3, 2,
#        2, 3, 3, 3, 2, 2, 2, 3, 2, 2, 2, 2, 3, 3, 3, 3, 2, 3, 2, 2, 3, 2,
#        3, 3, 3, 2, 3, 2, 4, 2, 3, 3, 2, 2, 2, 2, 3, 3, 3, 3, 3, 3, 2, 4,
#        3, 3, 2, 2, 3, 3, 2, 3, 2, 2, 2, 2, 3, 3, 3, 2, 3, 2, 2, 2, 2, 3,
# ...

# %%
result = pd.DataFrame({'Actual' : y_test, 'Predicted' : y_pred})
result
# Out:
#       Actual  Predicted
# 803        3          2
# 124        2          2
# 350        3          2
# 682        2          2
# 1326       3          3
# ...      ...        ...
# 1259       3          3
# 1295       2          2
# 1155       2          2
# 963        3          3
# 704        1          2
#
# [320 rows x 2 columns]

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.5625
